# %%
# Instalamos yfinance para bajar datos reales del mercado
# !pip install yfinance matplotlib pandas sqlalchemy

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3

print("¡Todo listo para empezar el proyecto!")
# Out:
# Requirement already satisfied: yfinance in c:\users\luna_\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: matplotlib in c:\users\luna_\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: pandas in c:\users\luna_\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in c:\users\luna_\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (4.0.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.15 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\luna_\anaconda3\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luna_\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\luna_\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\luna_\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\luna_\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\luna_\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\luna_\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\luna_\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.1.4)
# Requirement already satisfied: rich in c:\users\luna_\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (13.9.4)
# Requirement already satisfied: pycparser in c:\users\luna_\anaconda3\lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\luna_\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luna_\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luna_\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luna_\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\luna_\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\luna_\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\luna_\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.0)
# ¡Todo listo para empezar el proyecto!
